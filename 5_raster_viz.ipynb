# %% [markdown]
# # Raster Data Visualization
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/geog-312/blob/main/book/geospatial/raster_viz.ipynb)
#
# This notebook demonstrates how to visualize raster data using [leafmap](https://leafmap.org/). Leafmap can visualize raster data (e.g., Cloud Optimized GeoTIFF) stored in a local file or on the cloud (e.g., AWS S3). It can also visualize raster data stored in a [STAC](https://stacspec.org/) catalog.
#
# ## Installation
#
# Uncomment the following line to install the required packages if needed.

# %%
# !pip install "leafmap[raster]"
# Out:
# Collecting leafmap[raster]
#   Downloading leafmap-0.38.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting anywidget>=0.9.13 (from leafmap[raster])
#   Downloading anywidget-0.9.13-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: bqplot>=0.12.43 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.12.43)
# Requirement already satisfied: colour>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.1.5)
# Requirement already satisfied: folium>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.17.0)
# Requirement already satisfied: gdown>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (5.2.0)
# Collecting geojson>=3.1.0 (from leafmap[raster])
#   Downloading geojson-3.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipyevents>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.18.2 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.19.2)
# Collecting ipyvuetify>=1.9.4 (from leafmap[raster])
#   Downloading ipyvuetify-1.10.0-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets>=7.6.0 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (7.7.1)
# Requirement already satisfied: matplotlib>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (3.7.1)
# Requirement already satisfied: numpy<3.0.0,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (1.26.4)
# Requirement already satisfied: pandas>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (2.1.4)
# Requirement already satisfied: plotly>=5.15.0 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (5.24.1)
# Requirement already satisfied: psutil>=5.9.5 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (5.9.5)
# Requirement already satisfied: pyshp>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (2.3.1)
# Collecting pystac-client>=0.8.2 (from leafmap[raster])
#   Downloading pystac_client-0.8.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: python-box>=7.2.0 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (7.2.0)
# Requirement already satisfied: scooby>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.10.0)
# Requirement already satisfied: setuptools>=71.0.4 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (71.0.4)
# Collecting whiteboxgui>=2.3.0 (from leafmap[raster])
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: xyzservices>=2024.6.0 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (2024.9.0)
# Requirement already satisfied: duckdb>=0.10.3 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (1.1.0)
# Collecting localtileserver>=0.10.0 (from leafmap[raster])
#   Downloading localtileserver-0.10.3-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-server-proxy (from leafmap[raster])
#   Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting rio-cogeo (from leafmap[raster])
#   Downloading rio_cogeo-5.3.4-py3-none-any.whl.metadata (4.6 kB)
# Collecting rioxarray (from leafmap[raster])
#   Downloading rioxarray-0.17.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting netcdf4 (from leafmap[raster])
#   Downloading netCDF4-1.7.1.post2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting pynhd (from leafmap[raster])
#   Downloading pynhd-0.17.1-py3-none-any.whl.metadata (25 kB)
# Collecting py3dep (from leafmap[raster])
#   Downloading py3dep-0.17.1-py3-none-any.whl.metadata (20 kB)
# Collecting psygnal>=0.8.1 (from anywidget>=0.9.13->leafmap[raster])
#   Downloading psygnal-0.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from anywidget>=0.9.13->leafmap[raster]) (4.12.2)
# Requirement already satisfied: traitlets>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from bqplot>=0.12.43->leafmap[raster]) (5.7.1)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.10/dist-packages (from bqplot>=0.12.43->leafmap[raster]) (0.2.1)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium>=0.14.0->leafmap[raster]) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium>=0.14.0->leafmap[raster]) (3.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium>=0.14.0->leafmap[raster]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=5.1.0->leafmap[raster]) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown>=5.1.0->leafmap[raster]) (3.16.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown>=5.1.0->leafmap[raster]) (4.66.5)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from ipyleaflet>=0.18.2->leafmap[raster]) (0.19.2)
# Collecting ipyvue<2,>=1.7 (from ipyvuetify>=1.9.4->leafmap[raster])
#   Downloading ipyvue-1.11.1-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.0->leafmap[raster]) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.0->leafmap[raster]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.0->leafmap[raster]) (3.6.9)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.0->leafmap[raster]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.0->leafmap[raster]) (3.0.13)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from localtileserver>=0.10.0->leafmap[raster]) (8.1.7)
# Requirement already satisfied: flask<4,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from localtileserver>=0.10.0->leafmap[raster]) (2.2.5)
# Collecting Flask-Caching (from localtileserver>=0.10.0->leafmap[raster])
#   Downloading Flask_Caching-2.3.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver>=0.10.0->leafmap[raster])
#   Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting flask-restx>=0.5.0 (from localtileserver>=0.10.0->leafmap[raster])
#   Downloading flask_restx-1.3.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver>=0.10.0->leafmap[raster])
#   Downloading rio_tiler-6.7.0-py3-none-any.whl.metadata (11 kB)
# Collecting server-thread (from localtileserver>=0.10.0->leafmap[raster])
#   Downloading server_thread-0.2.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.10/dist-packages (from localtileserver>=0.10.0->leafmap[raster]) (3.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->leafmap[raster]) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->leafmap[raster]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->leafmap[raster]) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->leafmap[raster]) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->leafmap[raster]) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->leafmap[raster]) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->leafmap[raster]) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->leafmap[raster]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->leafmap[raster]) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->leafmap[raster]) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.15.0->leafmap[raster]) (9.0.0)
# Collecting pystac>=1.10.0 (from pystac[validation]>=1.10.0->pystac-client>=0.8.2->leafmap[raster])
#   Downloading pystac-1.10.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.10/dist-packages (from whiteboxgui>=2.3.0->leafmap[raster]) (0.2.2)
# Collecting whitebox (from whiteboxgui>=2.3.0->leafmap[raster])
#   Downloading whitebox-2.3.5-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->leafmap[raster]) (3.10.5)
# Requirement already satisfied: jupyter-server>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->leafmap[raster]) (1.24.0)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->leafmap[raster])
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: tornado>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->leafmap[raster]) (6.3.3)
# Collecting cftime (from netcdf4->leafmap[raster])
#   Downloading cftime-1.6.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from netcdf4->leafmap[raster]) (2024.8.30)
# Collecting async-retriever<0.18,>=0.17 (from py3dep->leafmap[raster])
#   Downloading async_retriever-0.17.1-py3-none-any.whl.metadata (16 kB)
# Collecting cytoolz (from py3dep->leafmap[raster])
#   Downloading cytoolz-0.12.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: geopandas>=0.10 in /usr/local/lib/python3.10/dist-packages (from py3dep->leafmap[raster]) (1.0.1)
# Collecting pygeoogc<0.18,>=0.17 (from py3dep->leafmap[raster])
#   Downloading pygeoogc-0.17.1-py3-none-any.whl.metadata (18 kB)
# Collecting pygeoutils<0.18,>=0.17 (from py3dep->leafmap[raster])
#   Downloading pygeoutils-0.17.1-py3-none-any.whl.metadata (12 kB)
# Collecting rasterio>=1.2 (from py3dep->leafmap[raster])
#   Downloading rasterio-1.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from py3dep->leafmap[raster]) (1.13.1)
# Requirement already satisfied: shapely>=2 in /usr/local/lib/python3.10/dist-packages (from py3dep->leafmap[raster]) (2.0.6)
# Requirement already satisfied: xarray>=2023.1 in /usr/local/lib/python3.10/dist-packages (from py3dep->leafmap[raster]) (2024.9.0)
# Requirement already satisfied: pyproj>=3.3 in /usr/local/lib/python3.10/dist-packages (from rioxarray->leafmap[raster]) (3.6.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pynhd->leafmap[raster]) (3.3)
# Requirement already satisfied: pyarrow>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from pynhd->leafmap[raster]) (14.0.2)
# Collecting morecantile<6.0,>=5.0 (from rio-cogeo->leafmap[raster])
#   Downloading morecantile-5.4.2-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.10/dist-packages (from rio-cogeo->leafmap[raster]) (2.9.2)
# Collecting aiohttp-client-cache>=0.8.1 (from async-retriever<0.18,>=0.17->py3dep->leafmap[raster])
#   Downloading aiohttp_client_cache-0.11.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting aiosqlite (from async-retriever<0.18,>=0.17->py3dep->leafmap[raster])
#   Downloading aiosqlite-0.20.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting ujson (from async-retriever<0.18,>=0.17->py3dep->leafmap[raster])
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (4.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask<4,>=2.0.0->localtileserver>=0.10.0->leafmap[raster]) (2.2.0)
# Collecting aniso8601>=0.82 (from flask-restx>=0.5.0->localtileserver>=0.10.0->leafmap[raster])
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver>=0.10.0->leafmap[raster]) (4.23.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver>=0.10.0->leafmap[raster]) (6.4.5)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.10->py3dep->leafmap[raster]) (0.9.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->leafmap[raster]) (6.1.12)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap[raster])
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap[raster]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap[raster]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap[raster]) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap[raster]) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap[raster]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap[raster]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap[raster]) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium>=0.14.0->leafmap[raster]) (2.1.5)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (3.7.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (23.1.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (5.7.2)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (6.5.4)
# Requirement already satisfied: nbformat>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (5.10.4)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.21.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (24.0.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.18.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.8.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic~=2.0->rio-cogeo->leafmap[raster]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic~=2.0->rio-cogeo->leafmap[raster]) (2.23.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from pygeoogc<0.18,>=0.17->py3dep->leafmap[raster]) (0.7.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from pygeoogc<0.18,>=0.17->py3dep->leafmap[raster]) (1.4.2)
# Collecting owslib>=0.27.2 (from pygeoogc<0.18,>=0.17->py3dep->leafmap[raster])
#   Downloading OWSLib-0.31.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting requests-cache>=0.9.6 (from pygeoogc<0.18,>=0.17->py3dep->leafmap[raster])
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting url-normalize>=1.4 (from pygeoogc<0.18,>=0.17->py3dep->leafmap[raster])
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pygeoogc<0.18,>=0.17->py3dep->leafmap[raster]) (2.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.1->leafmap[raster]) (1.16.0)
# Collecting affine (from rasterio>=1.2->py3dep->leafmap[raster])
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting cligj>=0.5 (from rasterio>=1.2->py3dep->leafmap[raster])
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio>=1.2->py3dep->leafmap[raster])
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium>=0.14.0->leafmap[raster]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium>=0.14.0->leafmap[raster]) (3.10)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap[raster]) (6.5.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=5.1.0->leafmap[raster]) (2.6)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from cytoolz->py3dep->leafmap[raster]) (0.12.1)
# Collecting cachelib<0.10.0,>=0.9.0 (from Flask-Caching->localtileserver>=0.10.0->leafmap[raster])
#   Downloading cachelib-0.9.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=5.1.0->leafmap[raster]) (1.7.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from rio-tiler->localtileserver>=0.10.0->leafmap[raster]) (5.5.0)
# Collecting color-operations (from rio-tiler->localtileserver>=0.10.0->leafmap[raster])
#   Downloading color_operations-0.1.5-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Collecting httpx (from rio-tiler->localtileserver>=0.10.0->leafmap[raster])
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from rio-tiler->localtileserver>=0.10.0->leafmap[raster]) (2.10.1)
# Collecting uvicorn (from server-thread->localtileserver>=0.10.0->leafmap[raster])
#   Downloading uvicorn-0.31.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting Brotli (from aiohttp[speedups]>=3.8.3->async-retriever<0.18,>=0.17->py3dep->leafmap[raster])
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.5 kB)
# Collecting aiodns>=3.2.0 (from aiohttp[speedups]>=3.8.3->async-retriever<0.18,>=0.17->py3dep->leafmap[raster])
#   Downloading aiodns-3.2.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.6.0->leafmap[raster]) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->flask-restx>=0.5.0->localtileserver>=0.10.0->leafmap[raster]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->flask-restx>=0.5.0->localtileserver>=0.10.0->leafmap[raster]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->flask-restx>=0.5.0->localtileserver>=0.10.0->leafmap[raster]) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (4.3.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (4.9.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (6.1.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.2.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (2.20.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap[raster]) (1.6.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap[raster]) (1.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from owslib>=0.27.2->pygeoogc<0.18,>=0.17->py3dep->leafmap[raster]) (6.0.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.6.0->leafmap[raster]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.6.0->leafmap[raster]) (0.2.13)
# Collecting cattrs>=22.2 (from requests-cache>=0.9.6->pygeoogc<0.18,>=0.17->py3dep->leafmap[raster])
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (21.2.0)
# Collecting httpcore==1.* (from httpx->rio-tiler->localtileserver>=0.10.0->leafmap[raster])
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->rio-tiler->localtileserver>=0.10.0->leafmap[raster])
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting pycares>=4.0.0 (from aiodns>=3.2.0->aiohttp[speedups]>=3.8.3->async-retriever<0.18,>=0.17->py3dep->leafmap[raster])
#   Downloading pycares-4.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap[raster]) (0.2.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.17.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (2.22)
# Downloading anywidget-0.9.13-py3-none-any.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.7/213.7 kB 4.7 MB/s eta 0:00:00
# Downloading geojson-3.1.0-py3-none-any.whl (15 kB)
# Downloading ipyvuetify-1.10.0-py2.py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 47.6 MB/s eta 0:00:00
# Downloading localtileserver-0.10.3-py3-none-any.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 57.0 MB/s eta 0:00:00
# Downloading pystac_client-0.8.3-py3-none-any.whl (33 kB)
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 9.0 MB/s eta 0:00:00
# Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl (37 kB)
# Downloading leafmap-0.38.1-py2.py3-none-any.whl (484 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.0/484.0 kB 25.3 MB/s eta 0:00:00
# Downloading netCDF4-1.7.1.post2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 60.6 MB/s eta 0:00:00
# Downloading py3dep-0.17.1-py3-none-any.whl (25 kB)
# Downloading rioxarray-0.17.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.4 MB/s eta 0:00:00
# Downloading pynhd-0.17.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 3.5 MB/s eta 0:00:00
# Downloading rio_cogeo-5.3.4-py3-none-any.whl (20 kB)
# Downloading async_retriever-0.17.1-py3-none-any.whl (16 kB)
# Downloading flask_restx-1.3.0-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 54.6 MB/s eta 0:00:00
# Downloading ipyvue-1.11.1-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 52.4 MB/s eta 0:00:00
# Downloading morecantile-5.4.2-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.1 MB/s eta 0:00:00
# Downloading psygnal-0.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (727 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.4/727.4 kB 33.2 MB/s eta 0:00:00
# Downloading pygeoogc-0.17.1-py3-none-any.whl (35 kB)
# Downloading pygeoutils-0.17.1-py3-none-any.whl (27 kB)
# Downloading pystac-1.10.1-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.9/182.9 kB 10.2 MB/s eta 0:00:00
# Downloading rasterio-1.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 25.9 MB/s eta 0:00:00
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Downloading cftime-1.6.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.6 MB/s eta 0:00:00
# Downloading cytoolz-0.12.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 59.5 MB/s eta 0:00:00
# Downloading Flask_Caching-2.3.0-py3-none-any.whl (28 kB)
# Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl (14 kB)
# Downloading rio_tiler-6.7.0-py3-none-any.whl (263 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.0/264.0 kB 20.1 MB/s eta 0:00:00
# Downloading server_thread-0.2.0-py3-none-any.whl (8.5 kB)
# Downloading whitebox-2.3.5-py2.py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 5.6 MB/s eta 0:00:00
# Downloading aiohttp_client_cache-0.11.1-py3-none-any.whl (32 kB)
# Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.4 MB/s eta 0:00:00
# Downloading cachelib-0.9.0-py3-none-any.whl (15 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Downloading OWSLib-0.31.0-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.1/233.1 kB 16.0 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 5.2 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading aiosqlite-0.20.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading color_operations-0.1.5-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.2/186.2 kB 15.3 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.2 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.0 MB/s eta 0:00:00
# Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.8 MB/s eta 0:00:00
# Downloading uvicorn-0.31.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.9 MB/s eta 0:00:00
# Downloading aiodns-3.2.0-py3-none-any.whl (5.7 kB)
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.2 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.9 MB/s eta 0:00:00
# Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 62.6 MB/s eta 0:00:00
# Downloading pycares-4.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 kB 16.8 MB/s eta 0:00:00
# Installing collected packages: Brotli, aniso8601, whitebox, url-normalize, ujson, simpervisor, psygnal, jedi, h11, geojson, cytoolz, color-operations, cligj, click-plugins, cftime, cattrs, cachelib, aiosqlite, affine, uvicorn, requests-cache, rasterio, pystac, pycares, owslib, netcdf4, httpcore, server-thread, morecantile, httpx, flask-cors, Flask-Caching, aiodns, rioxarray, rio-tiler, rio-cogeo, flask-restx, aiohttp-client-cache, pystac-client, pygeoutils, localtileserver, async-retriever, pygeoogc, pynhd, py3dep, jupyter-server-proxy, ipyvue, anywidget, whiteboxgui, ipyvuetify, leafmap
# Successfully installed Brotli-1.1.0 Flask-Caching-2.3.0 affine-2.4.0 aiodns-3.2.0 aiohttp-client-cache-0.11.1 aiosqlite-0.20.0 aniso8601-9.0.1 anywidget-0.9.13 async-retriever-0.17.1 cachelib-0.9.0 cattrs-24.1.2 cftime-1.6.4 click-plugins-1.1.1 cligj-0.7.2 color-operations-0.1.5 cytoolz-0.12.3 flask-cors-5.0.0 flask-restx-1.3.0 geojson-3.1.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 ipyvue-1.11.1 ipyvuetify-1.10.0 jedi-0.19.1 jupyter-server-proxy-4.4.0 leafmap-0.38.1 localtileserver-0.10.3 morecantile-5.4.2 netcdf4-1.7.1.post2 owslib-0.31.0 psygnal-0.11.1 py3dep-0.17.1 pycares-4.4.0 pygeoogc-0.17.1 pygeoutils-0.17.1 pynhd-0.17.1 pystac-1.10.1 pystac-client-0.8.3 rasterio-1.4.0 requests-cache-1.2.1 rio-cogeo-5.3.4 rio-tiler-6.7.0 rioxarray-0.17.0 server-thread-0.2.0 simpervisor-1.0.0 ujson-5.10.0 url-normalize-1.4.3 uvicorn-0.31.0 whitebox-2.3.5 whiteboxgui-2.3.0

# %% [markdown]
# ## Import packages

# %%
import leafmap

# %% [markdown]
# ## COG
#
# A Cloud Optimized GeoTIFF (COG) is a regular GeoTIFF file, aimed at being hosted on a HTTP file server, with an internal organization that enables more efficient workflows on the cloud. It does this by leveraging the ability of clients issuing HTTP GET range requests to ask for just the parts of a file they need. More information about COG can be found at <https://www.cogeo.org/in-depth.html>
#
# For this demo, we will use data from https://www.maxar.com/open-data/california-colorado-fires for mapping California and Colorado fires. Let's create an interactive map and add the COG to the map.

# %%
m = leafmap.Map()
url = "https://opendata.digitalglobe.com/events/california-fire-2020/pre-event/2018-02-16/pine-gulch-fire20/1030010076004E00.tif"
m.add_cog_layer(url, name="Fire (pre-event)")
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# You can add multiple COGs to the map. Let's add another COG to the map.

# %%
url2 = "https://opendata.digitalglobe.com/events/california-fire-2020/post-event/2020-08-14/pine-gulch-fire20/10300100AAC8DD00.tif"
m.add_cog_layer(url2, name="Fire (post-event)")
m
# Out:
# Map(center=[39.49489764407821, -108.5072786256228], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %% [markdown]
# ![](https://i.imgur.com/J9fLbYh.png)

# %% [markdown]
# Create a split map for comparing two COGs.

# %%
m = leafmap.Map()
m.split_map(left_layer=url, right_layer=url2)
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ![](https://i.imgur.com/FJa0Yta.png)

# %% [markdown]
# ## Local Raster
#
# Leafmap can also visualize local GeoTIFF files. Let's download some sample data

# %%
dem_url = "https://open.gishub.org/data/raster/srtm90.tif"
leafmap.download_file(dem_url, unzip=False)
# Out:
# Downloading...
# From: https://open.gishub.org/data/raster/srtm90.tif
# To: /content/srtm90.tif
# 100%|██████████| 16.6M/16.6M [00:00<00:00, 63.2MB/s]
# '/content/srtm90.tif'

# %% [markdown]
# Visualize a single-band raster.

# %%
m = leafmap.Map()
m.add_raster("srtm90.tif", cmap="terrain", layer_name="DEM")
m
# Out:
# Map(center=[37.630466999999996, -119.03021849999999], controls=(ZoomControl(options=['position', 'zoom_in_text…

# %% [markdown]
# ![](https://i.imgur.com/7g9huvY.png)

# %%
landsat_url = "https://open.gishub.org/data/raster/cog.tif"
leafmap.download_file(landsat_url)
# Out:
# Downloading...
# From: https://open.gishub.org/data/raster/cog.tif
# To: /content/cog.tif
# 100%|██████████| 611k/611k [00:00<00:00, 10.2MB/s]
# '/content/cog.tif'

# %% [markdown]
# Visualize a multi-band raster.

# %%
m = leafmap.Map()
m.add_raster("cog.tif", bands=[4, 3, 2], layer_name="Landsat")
m
# Out:
# Map(center=[53.4070895, 6.8754805], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %% [markdown]
# ![](https://i.imgur.com/euhkajs.png)

# %% [markdown]
# ## STAC
#
# The SpatioTemporal Asset Catalog (STAC) specification provides a common language to describe a range of geospatial information so that it can more easily be indexed and discovered. A SpatioTemporal Asset is any file that represents information about the earth captured in a certain space and time. STAC aims to enable that next generation of geospatial search engines, while also supporting web best practices so geospatial information is more easily surfaced in traditional search engines. More information about STAC can be found at the [STAC website](https://stacspec.org). In this example, we will use a STAC item from the [SPOT Orthoimages of Canada](https://stacindex.org/catalogs/spot-orthoimages-canada-2005) available through the link below:

# %% [markdown]
# Create an interactive map.

# %%
url = "https://canada-spot-ortho.s3.amazonaws.com/canada_spot_orthoimages/canada_spot5_orthoimages/S5_2007/S5_11055_6057_20070622/S5_11055_6057_20070622.json"
leafmap.stac_bands(url)

# %% [markdown]
# Add STAC layers to the map.

# %%
m = leafmap.Map()
m.add_stac_layer(url, bands=["pan"], name="Panchromatic")
m.add_stac_layer(url, bands=["B3", "B2", "B1"], name="False color")
m

# %% [markdown]
# ![](https://i.imgur.com/IlqsJXK.png)

# %% [markdown]
# ## Custom STAC Catalog

# %% [markdown]
# Provide custom STAC API endpoints as a dictionary in the format of `{"name": "url"}`. The name will show up in the dropdown menu, while the url is the STAC API endpoint that will be used to search for items.

# %%
catalogs = {
    "Element84 Earth Search": "https://earth-search.aws.element84.com/v1",
    "Microsoft Planetary Computer": "https://planetarycomputer.microsoft.com/api/stac/v1",
}

# %%
m = leafmap.Map(center=[40, -100], zoom=4)
m.set_catalog_source(catalogs)
m.add_stac_gui()
m

# %% [markdown]
# Once the catalog panel is open, you can search for items from the custom STAC API endpoints. Simply draw a bounding box on the map or zoom to a location of interest. Click on the **Collections** button to retrieve the collections from the custom STAC API endpoints. Next, select a collection from the dropdown menu. Then, click on the **Items** button to retrieve the items from the selected collection. Finally, click on the **Display** button to add the selected item to the map.

# %% [markdown]
# ![](https://i.imgur.com/M8IbRsM.png)

# %%
m.stac_gdf  # The GeoDataFrame of the STAC search results

# %%
m.stac_dict  # The STAC search results as a dictionary

# %%
m.stac_item  # The selected STAC item of the search result

# %% [markdown]
# ## AWS S3

# %% [markdown]
# To Be able to run this notebook you'll need to have AWS credential available as environment variables. Uncomment the following lines to set the environment variables.

# %%
# os.environ["AWS_ACCESS_KEY_ID"] = "YOUR AWS ACCESS ID HERE"
# os.environ["AWS_SECRET_ACCESS_KEY"] = "YOUR AWS ACCESS KEY HERE"

# %% [markdown]
# In this example, we will use datasets from the [Maxar Open Data Program on AWS](https://registry.opendata.aws/maxar-open-data/).

# %%
BUCKET = "maxar-opendata"
FOLDER = "events/Kahramanmaras-turkey-earthquake-23/"

# %% [markdown]
# List all the datasets in the bucket. Specify a file extension to filter the results if needed.

# %%
items = leafmap.s3_list_objects(BUCKET, FOLDER, ext=".tif")
items[:10]

# %% [markdown]
# Visualize raster datasets from the bucket.

# %%
m = leafmap.Map()
m.add_cog_layer(items[2], name="Maxar")
m

# %% [markdown]
# ![](https://i.imgur.com/NkTZ6Lj.png)
